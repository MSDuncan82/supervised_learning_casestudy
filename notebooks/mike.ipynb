# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import seaborn as sns
sys.path.append('/home/mike/dsi/case_studies/supervised-learning-case-study/src/')
from clean import clean
from sklearn.linear_model import LogisticRegression

# %%
df_raw = clean(pd.read_csv('../data/churn.csv'))

# %%
df_raw.active_user.sum()/50000
# Out:
# 0.37608

# %%
df_test = clean(df_test_raw)

# %%
df_test
# Out:
#       avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0         2.48                   5.0              5.000000       1.00
# 1        10.81                   5.0              5.000000       1.00
# 2        12.95                   5.0              5.000000       1.00
# 3         3.92                   5.0              4.601011       1.00
# 4         1.46                   5.0              4.500000       1.00
# ...        ...                   ...                   ...        ...
# 9995      2.11                   5.0              5.000000       1.00
# 9996      5.49                   4.9              4.100000       1.00
# 9997      2.49                   4.2              4.600000       1.25
# 9998      1.05                   4.0              5.000000       1.00
# 9999      6.31                   5.0              5.000000       1.00
#
#                 city last_trip_date    phone signup_date  surge_pct  \
# ...

# %%
df_test.describe()
# Out:
#            avg_dist  avg_rating_by_driver  avg_rating_of_driver     avg_surge  \
# count  10000.000000          10000.000000          10000.000000  10000.000000
# mean       5.818925              4.781056              4.601011      1.073996
# std        5.704789              0.440010              0.575169      0.221982
# min        0.000000              1.000000              1.000000      1.000000
# 25%        2.420000              4.700000              4.500000      1.000000
# 50%        3.890000              5.000000              4.800000      1.000000
# 75%        6.990000              5.000000              5.000000      1.050000
# max       79.340000              5.000000              5.000000      5.000000
#
#          surge_pct  trips_in_first_30_days   weekday_pct  months_as_user
# count  10000.00000            10000.000000  10000.000000    10000.000000
# mean       8.81831                2.268200     61.132890        3.051700
# ...

# %%
df_test

# %%
df_test.avg_rating_by_driver[df_test.avg_rating_by_driver.isna()]
# Out:
# Series([], Name: avg_rating_by_driver, dtype: float64)

# %%
df_test.corr()
# Out:
#                         avg_dist  avg_rating_by_driver  avg_rating_of_driver  \
# avg_dist                1.000000              0.073313              0.020912
# avg_rating_by_driver    0.073313              1.000000              0.117227
# avg_rating_of_driver    0.020912              0.117227              1.000000
# avg_surge              -0.089511              0.021599              0.002634
# surge_pct              -0.112794              0.025142              0.018493
# trips_in_first_30_days -0.140867             -0.038382             -0.001585
# luxury_car_user         0.058173              0.005394             -0.015687
# weekday_pct             0.118484              0.015828              0.017344
# active_user            -0.090429             -0.024065             -0.006317
# months_as_user         -0.103423             -0.027483             -0.012300
#
#                         avg_surge  surge_pct  trips_in_first_30_days  \
# ...

# %%
df_test.dtypes
# Out:
# avg_dist                         float64
# avg_rating_by_driver             float64
# avg_rating_of_driver             float64
# avg_surge                        float64
# city                              object
# last_trip_date            datetime64[ns]
# phone                             object
# signup_date               datetime64[ns]
# surge_pct                        float64
# trips_in_first_30_days             int64
# luxury_car_user                     bool
# weekday_pct                      float64
# active_user                         bool
# months_as_user                     int64
# dtype: object
